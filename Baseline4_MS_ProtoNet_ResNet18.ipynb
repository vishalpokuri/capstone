# %% [markdown]
# # Baseline 4 (Proposed): MS-ProtoNet with ResNet18 (MS-ProtoNet-18)
#
# This notebook implements the **proposed Multi-Scale Prototypical Network** using **ResNet18** as the backbone.
#
# ### Key idea (Novelty)
# - Extract features from **multiple ResNet layers**: layer2, layer3, layer4
# - Fuse these multi-scale features into a single embedding
# - Use Prototypical Networks for few-shot classification
#
# ### Optimization: Feature Caching
# To reduce training time, **intermediate layer features are cached** and reused across episodes instead of recomputing them every time.

# %% [markdown]
# ## 1. Imports

# %%
import os, random
import numpy as np
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models, transforms

from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Image Transform

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# %% [markdown]
# ## 3. ResNet18 Multi-Scale Feature Extractor
#
# We explicitly expose **layer2, layer3, and layer4 outputs**.
# These correspond to **low-, mid-, and high-level features**.

# %%
class ResNet18MultiScale(nn.Module):
    def __init__(self):
        super().__init__()
        base = models.resnet18(pretrained=True)

        # Explicit backbone blocks
        self.conv1 = base.conv1
        self.bn1 = base.bn1
        self.relu = base.relu
        self.maxpool = base.maxpool

        self.layer1 = base.layer1
        self.layer2 = base.layer2  # low/mid-level
        self.layer3 = base.layer3  # mid/high-level
        self.layer4 = base.layer4  # high-level

        # Global Average Pooling
        self.gap = nn.AdaptiveAvgPool2d((1, 1))

        # Projection layers to common dimension
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(256, 128)
        self.fc4 = nn.Linear(512, 128)

    def forward(self, x):
        # Forward pass with explicit annotation
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.maxpool(x)

        x = self.layer1(x)
        f2 = self.layer2(x)   # Feature level 1
        f3 = self.layer3(f2)  # Feature level 2
        f4 = self.layer4(f3)  # Feature level 3

        # Pooling
        v2 = self.gap(f2).view(f2.size(0), -1)
        v3 = self.gap(f3).view(f3.size(0), -1)
        v4 = self.gap(f4).view(f4.size(0), -1)

        # Projection
        z2 = self.fc2(v2)
        z3 = self.fc3(v3)
        z4 = self.fc4(v4)

        # Multi-scale fusion (concatenation)
        embedding = torch.cat([z2, z3, z4], dim=1)  # 384-D

        return embedding

# %% [markdown]
# ## 4. Feature Cache
#
# We cache multi-scale embeddings **per image** to avoid recomputation.
# This significantly speeds up episodic training.

# %%
class FeatureCache:
    def __init__(self):
        self.cache = {}

    def get(self, key):
        return self.cache.get(key, None)

    def set(self, key, value):
        self.cache[key] = value

# %% [markdown]
# ## 5. Few-Shot Dataset with Cached Features
#
# Images are passed through the backbone **once** and reused across episodes.

# %%
class FewShotDataset:
    def __init__(self, root, transform):
        self.root = root
        self.transform = transform

        self.classes = sorted(os.listdir(root))
        self.images = {
            c: [os.path.join(root, c, i) for i in os.listdir(os.path.join(root, c))]
            for c in self.classes
        }

    def sample_episode(self, n_way, k_shot, q_query):
        s_imgs, q_imgs, s_y, q_y = [], [], [], []
        classes = random.sample(self.classes, n_way)

        for label, cls in enumerate(classes):
            images = self.images[cls]

            # 🔒 Handle insufficient images by reuse
            if len(images) < (k_shot + q_query):
                print(
                    f"⚠️ Not enough images in class '{cls}'. "
                    f"Required={k_shot + q_query}, Available={len(images)}. Reusing images."
                )
                images = (
                    images * ((k_shot + q_query) // len(images) + 1)
                )[: k_shot + q_query]

            sampled_images = random.sample(images, k_shot + q_query)

            # Support set
            for img_path in sampled_images[:k_shot]:
                img = Image.open(img_path).convert("RGB")
                s_imgs.append(self.transform(img))
                s_y.append(label)

            # Query set
            for img_path in sampled_images[k_shot:]:
                img = Image.open(img_path).convert("RGB")
                q_imgs.append(self.transform(img))
                q_y.append(label)

        return (
            torch.stack(s_imgs),
            torch.tensor(s_y),
            torch.stack(q_imgs),
            torch.tensor(q_y),
        )

# %% [markdown]
# ## 6. Prototypical Network Head (Unchanged)

# %%
class ProtoNetHead(nn.Module):
    def forward(self, support_emb, support_y, query_emb):
        prototypes = []
        for c in torch.unique(support_y):
            prototypes.append(support_emb[support_y == c].mean(dim=0))
        prototypes = torch.stack(prototypes)

        distances = torch.cdist(query_emb, prototypes)
        return -distances

# %% [markdown]
# ## 7. Training & Evaluation

# %%
def train_and_evaluate(k_shot, episodes_train=100, episodes_eval=50):
    device = "cuda" if torch.cuda.is_available() else "cpu"

    encoder = ResNet18MultiScale().to(device)
    head = ProtoNetHead().to(device)

    # IMPORTANT: optimize BOTH encoder and head
    optimizer = torch.optim.Adam(
        list(encoder.parameters()) + list(head.parameters()),
        lr=1e-4
    )

    # Dataset returns IMAGES (not embeddings)
    train_data = FewShotDataset("clean_dataset/train", transform)
    val_data   = FewShotDataset("clean_dataset/val", transform)

    # =========================
    # TRAINING
    # =========================
    encoder.train()
    head.train()

    for ep in range(episodes_train):
        print(f"Training episode {ep + 1}/100...")
        # ---- sample episode (IMAGES) ----
        s_x, s_y, q_x, q_y = train_data.sample_episode(
            n_way=4, k_shot=k_shot, q_query=10
        )

        s_x, s_y = s_x.to(device), s_y.to(device)
        q_x, q_y = q_x.to(device), q_y.to(device)

        # ---- forward pass THROUGH encoder (CRITICAL) ----
        s_emb = encoder(s_x)
        q_emb = encoder(q_x)

        scores = head(s_emb, s_y, q_emb)
        loss = F.cross_entropy(scores, q_y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # =========================
    # EVALUATION
    # =========================
    encoder.eval()
    head.eval()

    all_preds, all_labels = [], []

    with torch.no_grad():
        for eval_episode in range(episodes_eval):
            print(f"Evaluating episode {eval_episode + 1}/50...")
            s_x, s_y, q_x, q_y = val_data.sample_episode(
                n_way=4, k_shot=k_shot, q_query=10
            )

            s_x, s_y = s_x.to(device), s_y.to(device)
            q_x, q_y = q_x.to(device), q_y.to(device)

            s_emb = encoder(s_x)
            q_emb = encoder(q_x)

            preds = head(s_emb, s_y, q_emb).argmax(dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(q_y.cpu().numpy())

    acc = accuracy_score(all_labels, all_preds)
    cm = confusion_matrix(all_labels, all_preds)

    return acc, cm

# %% [markdown]
# ## 8. Run 1-shot Experiments

# %%
print("=" * 50)
print("RUNNING 1-SHOT EXPERIMENTS")
print("=" * 50)

acc, cm = train_and_evaluate(1)
print(f"\nMS-ProtoNet-18 | {1}-Shot Accuracy: {acc:.4f}")

plt.figure(figsize=(4, 3))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["-K", "-N", "-P", "FN"],
            yticklabels=["-K", "-N", "-P", "FN"])
plt.title(f"Confusion Matrix ({1}-Shot)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# ==================================================
# RUNNING 1-SHOT EXPERIMENTS
# ==================================================
# Training episode 1/100...
# Training episode 2/100...
# Training episode 3/100...
# Training episode 4/100...
# Training episode 5/100...
# Training episode 6/100...
# Training episode 7/100...
# Training episode 8/100...
# Training episode 9/100...
# Training episode 10/100...
# Training episode 11/100...
# Training episode 12/100...
# Training episode 13/100...
# Training episode 14/100...
# Training episode 15/100...
# Training episode 16/100...
# Training episode 17/100...
# Training episode 18/100...
# Training episode 19/100...
# Training episode 20/100...
# Training episode 21/100...
# Training episode 22/100...
# Training episode 23/100...
# Training episode 24/100...
# Training episode 25/100...
# Training episode 26/100...
# Training episode 27/100...
# Training episode 28/100...
# Training episode 29/100...
# Training episode 30/100...
# Training episode 31/100...
# Training episode 32/100...
# Training episode 33/100...
# Training episode 34/100...
# Training episode 35/100...
# Training episode 36/100...
# Training episode 37/100...
# Training episode 38/100...
# Training episode 39/100...
# Training episode 40/100...
# Training episode 41/100...
# Training episode 42/100...
# Training episode 43/100...
# Training episode 44/100...
# Training episode 45/100...
# Training episode 46/100...
# Training episode 47/100...
# Training episode 48/100...
# Training episode 49/100...
# Training episode 50/100...
# Training episode 51/100...
# Training episode 52/100...
# Training episode 53/100...
# Training episode 54/100...
# Training episode 55/100...
# Training episode 56/100...
# Training episode 57/100...
# Training episode 58/100...
# Training episode 59/100...
# Training episode 60/100...
# Training episode 61/100...
# Training episode 62/100...
# Training episode 63/100...
# Training episode 64/100...
# Training episode 65/100...
# Training episode 66/100...
# Training episode 67/100...
# Training episode 68/100...
# Training episode 69/100...
# Training episode 70/100...
# Training episode 71/100...
# Training episode 72/100...
# Training episode 73/100...
# Training episode 74/100...
# Training episode 75/100...
# Training episode 76/100...
# Training episode 77/100...
# Training episode 78/100...
# Training episode 79/100...
# Training episode 80/100...
# Training episode 81/100...
# Training episode 82/100...
# Training episode 83/100...
# Training episode 84/100...
# Training episode 85/100...
# Training episode 86/100...
# Training episode 87/100...
# Training episode 88/100...
# Training episode 89/100...
# Training episode 90/100...
# Training episode 91/100...
# Training episode 92/100...
# Training episode 93/100...
# Training episode 94/100...
# Training episode 95/100...
# Training episode 96/100...
# Training episode 97/100...
# Training episode 98/100...
# Training episode 99/100...
# Training episode 100/100...
# Evaluating episode 1/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 2/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 3/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 4/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 5/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 6/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 7/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 8/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 9/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 10/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 11/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 12/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 13/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 14/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 15/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 16/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 17/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 18/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 19/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 20/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 21/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 22/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 23/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 24/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 25/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 26/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 27/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 28/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 29/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 30/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 31/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 32/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 33/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 34/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 35/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 36/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 37/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 38/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 39/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 40/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 41/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 42/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 43/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 44/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 45/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 46/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 47/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 48/50...
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# Evaluating episode 49/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
# Evaluating episode 50/50...
# ⚠️ Not enough images in class '-N'. Required=11, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=11, Available=8. Reusing images.
#
# MS-ProtoNet-18 | 1-Shot Accuracy: 0.9150

# %% [markdown]
# ## 9. Run 5-shot Experiments

# %%
print("=" * 50)
print("RUNNING 5-SHOT EXPERIMENTS")
print("=" * 50)

acc, cm = train_and_evaluate(5)
print(f"\nMS-ProtoNet-18 | {5}-Shot Accuracy: {acc:.4f}")

plt.figure(figsize=(4, 3))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["-K", "-N", "-P", "FN"],
            yticklabels=["-K", "-N", "-P", "FN"])
plt.title(f"Confusion Matrix ({5}-Shot)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# ==================================================
# RUNNING 5-SHOT EXPERIMENTS
# ==================================================
# /home/viscanum853/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/viscanum853/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Training episode 1/100...
# Training episode 2/100...
# Training episode 3/100...
# Training episode 4/100...
# Training episode 5/100...
# Training episode 6/100...
# Training episode 7/100...
# Training episode 8/100...
# Training episode 9/100...
# Training episode 10/100...
# Training episode 11/100...
# Training episode 12/100...
# Training episode 13/100...
# Training episode 14/100...
# Training episode 15/100...
# Training episode 16/100...
# Training episode 17/100...
# Training episode 18/100...
# Training episode 19/100...
# Training episode 20/100...
# Training episode 21/100...
# Training episode 22/100...
# Training episode 23/100...
# Training episode 24/100...
# Training episode 25/100...
# Training episode 26/100...
# Training episode 27/100...
# Training episode 28/100...
# Training episode 29/100...
# Training episode 30/100...
# Training episode 31/100...
# Training episode 32/100...
# Training episode 33/100...
# Training episode 34/100...
# Training episode 35/100...
# Training episode 36/100...
# Training episode 37/100...
# Training episode 38/100...
# Training episode 39/100...
# Training episode 40/100...
# Training episode 41/100...
# Training episode 42/100...
# Training episode 43/100...
# Training episode 44/100...
# Training episode 45/100...
# Training episode 46/100...
# Training episode 47/100...
# Training episode 48/100...
# Training episode 49/100...
# Training episode 50/100...
# Training episode 51/100...
# Training episode 52/100...
# Training episode 53/100...
# Training episode 54/100...
# Training episode 55/100...
# Training episode 56/100...
# Training episode 57/100...
# Training episode 58/100...
# Training episode 59/100...
# Training episode 60/100...
# Training episode 61/100...
# Training episode 62/100...
# Training episode 63/100...
# Training episode 64/100...
# Training episode 65/100...
# Training episode 66/100...
# Training episode 67/100...
# Training episode 68/100...
# Training episode 69/100...
# Training episode 70/100...
# Training episode 71/100...
# Training episode 72/100...
# Training episode 73/100...
# Training episode 74/100...
# Training episode 75/100...
# Training episode 76/100...
# Training episode 77/100...
# Training episode 78/100...
# Training episode 79/100...
# Training episode 80/100...
# Training episode 81/100...
# Training episode 82/100...
# Training episode 83/100...
# Training episode 84/100...
# Training episode 85/100...
# Training episode 86/100...
# Training episode 87/100...
# Training episode 88/100...
# Training episode 89/100...
# Training episode 90/100...
# Training episode 91/100...
# Training episode 92/100...
# Training episode 93/100...
# Training episode 94/100...
# Training episode 95/100...
# Training episode 96/100...
# Training episode 97/100...
# Training episode 98/100...
# Training episode 99/100...
# Training episode 100/100...
# Evaluating episode 1/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# Evaluating episode 2/50...
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# Evaluating episode 3/50...
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# Evaluating episode 4/50...
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# Evaluating episode 5/50...
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# Evaluating episode 6/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# Evaluating episode 7/50...
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# Evaluating episode 8/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# Evaluating episode 9/50...
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# Evaluating episode 10/50...
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# Evaluating episode 11/50...
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# Evaluating episode 12/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# Evaluating episode 13/50...
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# Evaluating episode 14/50...
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# Evaluating episode 15/50...
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# Evaluating episode 16/50...
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# Evaluating episode 17/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# Evaluating episode 18/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# Evaluating episode 19/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# Evaluating episode 20/50...
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# Evaluating episode 21/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# Evaluating episode 22/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# Evaluating episode 23/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# Evaluating episode 24/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# Evaluating episode 25/50...
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# Evaluating episode 26/50...
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# Evaluating episode 27/50...
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# Evaluating episode 28/50...
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# Evaluating episode 29/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# Evaluating episode 30/50...
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# Evaluating episode 31/50...
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# Evaluating episode 32/50...
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# Evaluating episode 33/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# Evaluating episode 34/50...
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# Evaluating episode 35/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# Evaluating episode 36/50...
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# Evaluating episode 37/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# Evaluating episode 38/50...
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# Evaluating episode 39/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# Evaluating episode 40/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# Evaluating episode 41/50...
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# Evaluating episode 42/50...
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# Evaluating episode 43/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# Evaluating episode 44/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# Evaluating episode 45/50...
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# Evaluating episode 46/50...
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# Evaluating episode 47/50...
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# Evaluating episode 48/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# Evaluating episode 49/50...
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# Evaluating episode 50/50...
# ⚠️ Not enough images in class '-N'. Required=15, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=15, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=15, Available=8. Reusing images.
#
# MS-ProtoNet-18 | 5-Shot Accuracy: 0.9860

# %% [markdown]
# ## 10. Run 10-shot Experiments

# %%
print("=" * 50)
print("RUNNING 10-SHOT EXPERIMENTS")
print("=" * 50)

acc, cm = train_and_evaluate(10)
print(f"\nMS-ProtoNet-18 | {10}-Shot Accuracy: {acc:.4f}")

plt.figure(figsize=(4, 3))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["-K", "-N", "-P", "FN"],
            yticklabels=["-K", "-N", "-P", "FN"])
plt.title(f"Confusion Matrix ({10}-Shot)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# ==================================================
# RUNNING 10-SHOT EXPERIMENTS
# ==================================================
# /home/viscanum853/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/viscanum853/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Training episode 1/100...
# Training episode 2/100...
# Training episode 3/100...
# Training episode 4/100...
# Training episode 5/100...
# Training episode 6/100...
# Training episode 7/100...
# Training episode 8/100...
# Training episode 9/100...
# Training episode 10/100...
# Training episode 11/100...
# Training episode 12/100...
# Training episode 13/100...
# Training episode 14/100...
# Training episode 15/100...
# Training episode 16/100...
# Training episode 17/100...
# Training episode 18/100...
# Training episode 19/100...
# Training episode 20/100...
# Training episode 21/100...
# Training episode 22/100...
# Training episode 23/100...
# Training episode 24/100...
# Training episode 25/100...
# Training episode 26/100...
# Training episode 27/100...
# Training episode 28/100...
# Training episode 29/100...
# Training episode 30/100...
# Training episode 31/100...
# Training episode 32/100...
# Training episode 33/100...
# Training episode 34/100...
# Training episode 35/100...
# Training episode 36/100...
# Training episode 37/100...
# Training episode 38/100...
# Training episode 39/100...
# Training episode 40/100...
# Training episode 41/100...
# Training episode 42/100...
# Training episode 43/100...
# Training episode 44/100...
# Training episode 45/100...
# Training episode 46/100...
# Training episode 47/100...
# Training episode 48/100...
# Training episode 49/100...
# Training episode 50/100...
# Training episode 51/100...
# Training episode 52/100...
# Training episode 53/100...
# Training episode 54/100...
# Training episode 55/100...
# Training episode 56/100...
# Training episode 57/100...
# Training episode 58/100...
# Training episode 59/100...
# Training episode 60/100...
# Training episode 61/100...
# Training episode 62/100...
# Training episode 63/100...
# Training episode 64/100...
# Training episode 65/100...
# Training episode 66/100...
# Training episode 67/100...
# Training episode 68/100...
# Training episode 69/100...
# Training episode 70/100...
# Training episode 71/100...
# Training episode 72/100...
# Training episode 73/100...
# Training episode 74/100...
# Training episode 75/100...
# Training episode 76/100...
# Training episode 77/100...
# Training episode 78/100...
# Training episode 79/100...
# Training episode 80/100...
# Training episode 81/100...
# Training episode 82/100...
# Training episode 83/100...
# Training episode 84/100...
# Training episode 85/100...
# Training episode 86/100...
# Training episode 87/100...
# Training episode 88/100...
# Training episode 89/100...
# Training episode 90/100...
# Training episode 91/100...
# Training episode 92/100...
# Training episode 93/100...
# Training episode 94/100...
# Training episode 95/100...
# Training episode 96/100...
# Training episode 97/100...
# Training episode 98/100...
# Training episode 99/100...
# Training episode 100/100...
# Evaluating episode 1/50...
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# Evaluating episode 2/50...
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# Evaluating episode 3/50...
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# Evaluating episode 4/50...
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# Evaluating episode 5/50...
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# Evaluating episode 6/50...
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# Evaluating episode 7/50...
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# Evaluating episode 8/50...
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# Evaluating episode 9/50...
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# Evaluating episode 10/50...
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# Evaluating episode 11/50...
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# Evaluating episode 12/50...
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# Evaluating episode 13/50...
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# Evaluating episode 14/50...
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# Evaluating episode 15/50...
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# Evaluating episode 16/50...
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# Evaluating episode 17/50...
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# Evaluating episode 18/50...
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# Evaluating episode 19/50...
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# Evaluating episode 20/50...
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# Evaluating episode 21/50...
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# Evaluating episode 22/50...
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# Evaluating episode 23/50...
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# Evaluating episode 24/50...
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# Evaluating episode 25/50...
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# Evaluating episode 26/50...
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# Evaluating episode 27/50...
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# Evaluating episode 28/50...
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# Evaluating episode 29/50...
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# Evaluating episode 30/50...
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# Evaluating episode 31/50...
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# Evaluating episode 32/50...
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# Evaluating episode 33/50...
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# Evaluating episode 34/50...
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# Evaluating episode 35/50...
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# Evaluating episode 36/50...
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# Evaluating episode 37/50...
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# Evaluating episode 38/50...
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# Evaluating episode 39/50...
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# Evaluating episode 40/50...
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# Evaluating episode 41/50...
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# Evaluating episode 42/50...
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# Evaluating episode 43/50...
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# Evaluating episode 44/50...
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# Evaluating episode 45/50...
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# Evaluating episode 46/50...
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# Evaluating episode 47/50...
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# Evaluating episode 48/50...
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# Evaluating episode 49/50...
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
# Evaluating episode 50/50...
# ⚠️ Not enough images in class '-P'. Required=20, Available=8. Reusing images.
# ⚠️ Not enough images in class '-K'. Required=20, Available=14. Reusing images.
# ⚠️ Not enough images in class '-N'. Required=20, Available=8. Reusing images.
#
# MS-ProtoNet-18 | 10-Shot Accuracy: 0.9350

# %%
import pandas as pd

data = {
    'Shots': [1, 5, 10],
    'Accuracy': [0.9150, 0.9860, 0.9350]
}

df = pd.DataFrame(data)

# Derive Percentage from Accuracy
df["Percentage"] = df["Accuracy"]

styled_df = (
    df.style
      .set_caption("Baseline 4: MS-ProtoNet-18")
      .format({
          "Accuracy": "{:.4f}",
          "Percentage": "{:.2%}"
      })
      .set_properties(**{"text-align": "center"})
)

styled_df
# Out:
# <style type="text/css">
# #T_6b289_row0_col0, #T_6b289_row0_col1, #T_6b289_row0_col2, #T_6b289_row1_col0, #T_6b289_row1_col1, #T_6b289_row1_col2, #T_6b289_row2_col0, #T_6b289_row2_col1, #T_6b289_row2_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_6b289">
#   <caption>Baseline 4: MS-ProtoNet-18</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b289_level0_col0" class="col_heading level0 col0" >Shots</th>
#       <th id="T_6b289_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_6b289_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b289_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6b289_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_6b289_row0_col1" class="data row0 col1" >0.9150</td>
#       <td id="T_6b289_row0_col2" class="data row0 col2" >91.50%</td>
#     </tr>
#     <tr>
#       <th id="T_6b289_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6b289_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_6b289_row1_col1" class="data row1 col1" >0.9860</td>
#       <td id="T_6b289_row1_col2" class="data row1 col2" >98.60%</td>
#     </tr>
#     <tr>
#       <th id="T_6b289_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6b289_row2_col0" class="data row2 col0" >10</td>
#       <td id="T_6b289_row2_col1" class="data row2 col1" >0.9350</td>
#       <td id="T_6b289_row2_col2" class="data row2 col2" >93.50%</td>
#     </tr>
#   </tbody>
# </table>
